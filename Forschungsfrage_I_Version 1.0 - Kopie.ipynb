# %%
# Out:
#   File "<ipython-input-19-a848285a8530>", line 16
#     #data = pd.read_sql(sql=sql_query, con=engine)
#                                                   ^
# SyntaxError: unexpected EOF while parsing

# %%
import pandas as pd
import os

data=pd.read_excel('daten_.xlsx')

data.head(10)
# Out:
#          id                                              title  \
# 0  37992108                   My html form won't POST to mysql
# 1  38039505    Counting number of characters in a WCHAR string
# 2  30864424            How to get the appropriate ComboBox Tag
# 3  31033371                       Angular loop is not updating
# 4  30769186  why vector is always slower than C array, at l...
# 5  11926566  jQuery Accordion Tab - Link to site, not page ...
# 6  25651501          Is there java.io.Reader equivalent in Go?
# 7  25452101  NullPointerException while trying to bind at S...
# 8  25554344  Calculate input of textbox and update another ...
# 9  25409238  Select File Name created with Date and Time fo...
#
#                                                 body  accepted_answer_id  \
# 0  <p>Hello i have a problem where my data isn't ...            37994134
# 1  <p>Lua has a function named <code>utf8.len()</...            38083489
# 2  <p>I'm trying to get the Tag associated to a v...            30865517
# 3  <p>Just started out with angular. I was succes...            31034475
# 4  <p>I am trying to find all the primes not grea...            30769515
# 5  <p>I've currently have 5 tabs on my jQuery Acc...            11927006
# 6  <p>Go has very nice <code>io.Reader</code> and...            25652169
# 7  <p>I have asked <a href="https://stackoverflow...            25473115
# 8  <p>my UI - <a href="http://puu.sh/bbx5G/33953b...            25554940
# 9  <pre><code> NSString *dateString= [self curren...            25410236
#
#    answer_count  comment_count community_owned_date  \
# 0             1             16                  NaN
# 1             1             25                  NaN
# 2             2             10                  NaN
# 3             2             13                  NaN
# 4             1             36                  NaN
# 5             1              0                  NaN
# 6             1              7                  NaN
# 7             3              7                  NaN
# 8             3              7                  NaN
# 9             1              8                  NaN
#
#                  creation_date  favorite_count           last_activity_date  \
# 0  2016-06-23 12:47:34.017 UTC             0.0    2016-06-23 14:11:39.8 UTC
# 1  2016-06-26 14:29:23.597 UTC             NaN  2016-06-28 18:15:46.893 UTC
# 2   2015-06-16 10:01:14.49 UTC             0.0  2015-06-18 19:15:43.763 UTC
# 3  2015-06-24 17:40:05.553 UTC             NaN  2015-06-24 20:04:45.793 UTC
# 4   2015-06-10 23:43:19.39 UTC             NaN   2015-06-11 00:50:01.66 UTC
# 5  2012-08-12 23:09:29.383 UTC             NaN  2012-08-13 22:59:39.523 UTC
# 6  2014-09-03 18:44:49.767 UTC             NaN  2015-07-23 10:02:59.063 UTC
# 7   2014-08-22 16:58:47.14 UTC             NaN  2014-08-24 15:11:28.927 UTC
# 8   2014-08-28 17:08:57.26 UTC             NaN  2014-08-28 19:08:59.697 UTC
# 9   2014-08-20 15:54:00.95 UTC             0.0  2014-08-20 16:48:06.023 UTC
#
#    ...             last_edit_date_1 last_editor_display_name_1  \
# 0  ...                          NaN                        NaN
# 1  ...                          NaN                        NaN
# 2  ...  2015-06-16 12:25:59.613 UTC                        NaN
# 3  ...                          NaN                        NaN
# 4  ...   2015-06-11 00:50:01.66 UTC                        NaN
# 5  ...  2012-08-13 22:59:39.523 UTC                        NaN
# 6  ...                          NaN                        NaN
# 7  ...                          NaN                        NaN
# 8  ...  2014-08-28 18:04:28.743 UTC                        NaN
# 9  ...                          NaN                        NaN
#
#    last_editor_user_id_1 owner_display_name_1  owner_user_id_1  parent_id_1  \
# 0                    NaN                  NaN        6498280.0     37992108
# 1                    NaN                  NaN        3408572.0     38039505
# 2              4984854.0                  NaN        4984854.0     30864424
# 3                    NaN                  NaN        2435473.0     31033371
# 4               257645.0                  NaN         257645.0     30769186
# 5              1592971.0                  NaN        1592971.0     11926566
# 6                    NaN                  NaN         145587.0     25651501
# 7                    NaN                  NaN        2175647.0     25452101
# 8              3799191.0                  NaN        3799191.0     25554344
# 9                    NaN                  NaN        2891273.0     25409238
#
#    post_type_id_1  score_1 tags_1  view_count_1
# 0               2        0    NaN           NaN
# 1               2        1    NaN           NaN
# 2               2        1    NaN           NaN
# 3               2        1    NaN           NaN
# 4               2        7    NaN           NaN
# 5               2        1    NaN           NaN
# 6               2        3    NaN           NaN
# 7               2        0    NaN           NaN
# 8               2        1    NaN           NaN
# 9               2        0    NaN           NaN
#
# [10 rows x 40 columns]

# %%
data.columns
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 40 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          10000 non-null  int64
#  1   title                       10000 non-null  object
#  2   body                        10000 non-null  object
#  3   accepted_answer_id          10000 non-null  int64
#  4   answer_count                10000 non-null  int64
#  5   comment_count               10000 non-null  int64
#  6   community_owned_date        4 non-null      object
#  7   creation_date               10000 non-null  object
#  8   favorite_count              2669 non-null   float64
#  9   last_activity_date          10000 non-null  object
#  10  last_edit_date              5612 non-null   object
#  11  last_editor_display_name    144 non-null    object
#  12  last_editor_user_id         5524 non-null   float64
#  13  owner_display_name          267 non-null    object
#  14  owner_user_id               9817 non-null   float64
#  15  parent_id                   0 non-null      float64
#  16  post_type_id                10000 non-null  int64
#  17  score                       10000 non-null  int64
#  18  tags                        10000 non-null  object
#  19  view_count                  10000 non-null  int64
#  20  id_1                        10000 non-null  int64
#  21  title_1                     0 non-null      float64
#  22  body_1                      10000 non-null  object
#  23  accepted_answer_id_1        0 non-null      float64
#  24  answer_count_1              0 non-null      float64
#  25  comment_count_1             10000 non-null  int64
#  26  community_owned_date_1      16 non-null     object
#  27  creation_date_1             10000 non-null  object
#  28  favorite_count_1            0 non-null      float64
#  29  last_activity_date_1        10000 non-null  object
#  30  last_edit_date_1            3587 non-null   object
#  31  last_editor_display_name_1  41 non-null     object
#  32  last_editor_user_id_1       3562 non-null   float64
#  33  owner_display_name_1        150 non-null    object
#  34  owner_user_id_1             9926 non-null   float64
#  35  parent_id_1                 10000 non-null  int64
#  36  post_type_id_1              10000 non-null  int64
#  37  score_1                     10000 non-null  int64
#  38  tags_1                      0 non-null      float64
#  39  view_count_1                0 non-null      float64
# dtypes: float64(12), int64(12), object(16)
# memory usage: 3.1+ MB

# %%
taggs = data[['id','title','body','tags']]
my_liste=[]
for i in range(10000):
    my_liste.append(" ")
taggs.insert(4,"Product_Categories",my_liste,True)
taggs.head()
# Out:
#          id                                              title  \
# 0  37992108                   My html form won't POST to mysql
# 1  38039505    Counting number of characters in a WCHAR string
# 2  30864424            How to get the appropriate ComboBox Tag
# 3  31033371                       Angular loop is not updating
# 4  30769186  why vector is always slower than C array, at l...
#
#                                                 body  \
# 0  <p>Hello i have a problem where my data isn't ...
# 1  <p>Lua has a function named <code>utf8.len()</...
# 2  <p>I'm trying to get the Tag associated to a v...
# 3  <p>Just started out with angular. I was succes...
# 4  <p>I am trying to find all the primes not grea...
#
#                                             tags Product_Categories
# 0                            php|html|mysql|post
# 1                           c|winapi|unicode|lua
# 2                                c#|wpf|combobox
# 3  javascript|php|mysql|angularjs|angularjs-http
# 4                              c++|arrays|vector

# %%
Tags_list=taggs['tags'].tolist()
print(Tags_list)
# Out:
# ['php|html|mysql|post', 'c|winapi|unicode|lua', 'c#|wpf|combobox', 'javascript|php|mysql|angularjs|angularjs-http', 'c++|arrays|vector', 'jquery|html', 'go', 'android', 'javascript|jquery|html', 'php|ios|objective-c|xcode|nsdocument', 'javascript|jquery|html|css', 'php|dreamweaver|custom-type', 'c#|list|date|datetime', 'c#|sql|sql-server', 'python|pymssql', 'android|android-intent|spotify', 'c#|.net|entity-framework|transactions', 'c#|excel|exception|interop|add-in', 'c#|arrays|string', 'c#|windows-8|zipfile', 'javascript', 'javascript', 'c|pointers|memory|memory-leaks|valgrind', 'javascript|javascript-events|event-handling|jquery', 'jquery', 'c#|c#-4.0', 'android|android-intent', 'php|excel|import|excel-2007', 'php|mysql|database-connection', 'haskell|redis|connection-string|unix-socket', 'html|css', 'angularjs', 'android|google-maps', 'c#|ef-code-first|foreign-keys|entity-framework-5|ef-database-first', 'java|search|multidimensional-array', 'php|mysql|arrays|pdo|echo', 'c#|asp.net-mvc', 'ruby-on-rails|polymorphism|has-many-through|polymorphic-associations', 'javascript|php|jquery', 'c++|cmake', 'javascript|jquery|backbone.js|render|timing', 'javascript|jquery|jquery-animate', 'iphone|ios|sentestingkit', 'oracle|plsql|data-dictionary', 'java|geometry|polygon', 'javascript|css|html|background|tinymce', 'php|jquery|phpquery', 'javascript|asp.net', 'javascript|jquery|html', 'r|openstreetmap', 'java', 'python|python-2.7', 'javascript|php|browser', 'c++|c|malloc', 'mysql|csv|primary-key', 'java|variadic-functions', 'php|zend-framework|zend-controller', 'javascript|jquery|iframe|google-chrome-extension', 'java|matrix|classification|tf-idf', 'php|zend-server', 'asp.net-mvc', 'ruby|facebook', 'haskell', 'java|swing|look-and-feel', 'java|decimalformat', 'python|django|authentication', 'javascript|jquery', 'c++|boost|boost-asio', 'javascript|jquery|asp.net-mvc-3|razor', 'php|html|forms|codeigniter', 'java|console-application|poker', 'mysql|pdo', 'c++|compiler-errors|xsd|xerces|codesynthesis', 'php|mysql|database|yii', 'java|c#|oop', 'c|io|double|printf', 'multithreading|perl', 'java|sql|syntax', 'xcode|app-store-connect', 'php|mysql|ios|notifications|push', 'c++|operator-overloading', 'c++|algorithm', 'php|arrays|sorting', 'android|android-fragments|back-stack', 'php|laravel|controller|routes|laravel-routing', 'git|msysgit', 'jprofiler', 'java|jdb', 'iis|powershell|web-administration', 'sql|sql-server|pivot', 'c++', 'php|html|string|append', 'java|class|inheritance', 'entity-framework|code-first', 'java|arrays|extends', 'c#|.net|windows', 'android|position|sensors', 'python|decorator|metaclass', 'java|compiler-construction|obfuscation|javac', 'hadoop|amazon-s3|elastic-map-reduce|amazon-emr', 'java|json|jakarta-ee', 'html|html5-canvas|easeljs', 'jquery-ui|jquery', 'jquery|element', 'c#|.net|wcf|serialization|partial-classes', 'html|contenteditable', 'python|django|base64', 'java|generics|junit', 'c++|network-programming', 'sql|sql-server-2008', 'java|swing|jtable', 'ruby|build|msbuild|rake|target', 'redis|servicestack', 'python|delegates|circular-reference', 'vim|makefile', 'jquery|internet-explorer', 'mysql|zend-framework|stored-procedures', 'wordpress|node.js|password-encryption', 'scala|option|type-erasure', 'java|compiler-construction|java-compiler-api', 'delphi|delphi-xe2|richedit', 'python|programming-languages', 'python|numpy|machine-learning|lda|topic-modeling', 'haskell|dependencies|cabal', 'ninject|aop|ninject-interception', 'php|codeigniter|date|json', 'java|ssl', 'go|reflection|go-reflect', 'ruby-on-rails', 'php|zend-framework', 'javascript|jquery|datetime', 'sql-server|sql-server-2005|tsql|sql-server-2008', 'c#|asp.net|drop-down-menu|aspxgridview', 'android|listview|click', 'c#|wpf|linq', 'uiview|ios4|uibutton|uiwindow', 'php|sql', 'javascript|jquery', 'asp.net|linq|list|comparison', 'c#|.net', 'php|regex|preg-match', 'java|android|performance|android-ndk', 'c#|.net|lambda', 'c#|silverlight|windows-phone-7', 'iphone', 'r|da ...

# %%
split_set=[]

for i in Tags_list: 
     split_set.append(i.split('|')[0])

             
print(split_set)
# Out:
# ['php', 'c', 'c#', 'javascript', 'c++', 'jquery', 'go', 'android', 'javascript', 'php', 'javascript', 'php', 'c#', 'c#', 'python', 'android', 'c#', 'c#', 'c#', 'c#', 'javascript', 'javascript', 'c', 'javascript', 'jquery', 'c#', 'android', 'php', 'php', 'haskell', 'html', 'angularjs', 'android', 'c#', 'java', 'php', 'c#', 'ruby-on-rails', 'javascript', 'c++', 'javascript', 'javascript', 'iphone', 'oracle', 'java', 'javascript', 'php', 'javascript', 'javascript', 'r', 'java', 'python', 'javascript', 'c++', 'mysql', 'java', 'php', 'javascript', 'java', 'php', 'asp.net-mvc', 'ruby', 'haskell', 'java', 'java', 'python', 'javascript', 'c++', 'javascript', 'php', 'java', 'mysql', 'c++', 'php', 'java', 'c', 'multithreading', 'java', 'xcode', 'php', 'c++', 'c++', 'php', 'android', 'php', 'git', 'jprofiler', 'java', 'iis', 'sql', 'c++', 'php', 'java', 'entity-framework', 'java', 'c#', 'android', 'python', 'java', 'hadoop', 'java', 'html', 'jquery-ui', 'jquery', 'c#', 'html', 'python', 'java', 'c++', 'sql', 'java', 'ruby', 'redis', 'python', 'vim', 'jquery', 'mysql', 'wordpress', 'scala', 'java', 'delphi', 'python', 'python', 'haskell', 'ninject', 'php', 'java', 'go', 'ruby-on-rails', 'php', 'javascript', 'sql-server', 'c#', 'android', 'c#', 'uiview', 'php', 'javascript', 'asp.net', 'c#', 'php', 'java', 'c#', 'c#', 'iphone', 'r', 'javascript', 'c#', 'java', 'java', 'javascript', 'ruby-on-rails', 'sql', 'javascript', 'c++', 'javascript', 'adobe', 'c#', 'sql-server', 'php', 'java', 'jquery', 'asp.net-mvc', 'python', 'c++', 'asp.net', 'java', 'c#', 'c++', 'unix', 'javascript', 'javascript', '.net', 'c#', 'c#', 'java', 'python', 'c#', 'c#', 'linq', 'java', 'java', 'database', 'git', 'jquery', 'objective-c', 'entity-framework', 'c#', 'java', '.net', 'php', 'jquery', 'sqlite', 'actionscript-3', 'c#', 'jquery', 'c', 'java', 'javascript', 'mysql', 'python', 'python', 'java', 'python', 'c++', 'ios', 'php', 'arrays', 'c++', 'mysql', 'objective-c', '.net', 'javascript', 'html', 'actionscript-3', 'iphone', 'iphone', 'iphone', 'jquery', 'mercurial', 'java', 'ruby-on-rails', 'django', 'php', 'testing', 'php', 'c++', 'android', 'jquery', 'c#', 'iphone', 'forms', 'sql-server-2008', 'sql', 'python', 'ios', 'html', 'android', 'bash', 'powershell', 'c++', 'c#', 'java', 'c#', 'git', 'php', 'java', 'asp.net', 'objective-c', 'regex', 'salesforce', '.net', 'c#', 'asp.net', 'sql', 'eclipse', 'c#', 'sql', 'c#', 'c#', '.net', 'php', 'html', 'javascript', 'testing', 'php', 'http', 'c#', 'java', 'sql', 'database-design', 'php', 'c', 'javascript', 'ruby-on-rails', 'python', 'ms-access', 'cocoa-touch', 'java', 'flash', 'asp.net', 'sql-server', 'web-services', '.net', 'data-binding', 'javascript', 'ruby', 'algorithm', 'makefile', 'python', 'list', 'asp.net-mvc', 'php', 'php', 'php', 'database', '.net', 'oracle', 'android', 'django', 'c', 'joomla', 'c#', 'javascript', 'php', 'javascript', 'asp.net', 'javascript', 'sql', 'c#', 'php', 'security', 'c#', 'c#', 'jquery', 'c#', 'c++', 'delphi', 'javascript', 'sql', 'windows', 'asp.net-mvc', 'php', 'c++', 'c++', 'c++', 'sqlite', 'css', 'android', 'java', 'java', 'c++', 'java', 'c#', 'java', 'php', 'java', 'google-drive-api', 'android', 'ruby-on-rails', 'c#', 'cassandra', 'android', 'css', 'c#', 'java', 'java', 'arrays', 'ruby-on-rails-3', 'c++', 'installation', 'image', 'php', 'r', 'c#', 'javascript', 'asp.net-mvc-3', 'windows', 'java', 'github', 'linux', 'php', 'php', 'trigger.io', 'php', 'javascript', 'sql', 'php', 'python', 'version-control', 'android', 'r', 'php', 'r', 'ios', 'json', 'php', 'watir', 'java', 'java', 'html', 'css', 'php', 'java', 'ios', 'mime-types', 'java', 'android', 'php', 'javascript', 'javascript', 'javascript', 'algorithm', 'c#', 'macos', 'javascript', 'c#', 'c#', 'import', 'iphone', 'javascript', 'c#', 'nginx', 'sql-server', 'java', 'php', 'mysql', 'mysql', 'excel', 'c#', 'javascript', 'php', 'android', 'excel', 'magento', 'php', 'javascript-events', 'ruby-on-rails', 'wpf', 'windows', 'java', 'c++', ...

# %%
from collections import Counter
counted_results=Counter(split_set)
sorted_values=sorted(counted_results.values())

# %%
print(counted_results)
# Out:
# Counter({'javascript': 1060, 'java': 804, 'python': 790, 'c#': 779, 'php': 657, 'android': 386, 'c++': 340, 'ios': 244, 'sql': 209, 'jquery': 206, 'r': 199, 'html': 188, 'c': 187, 'ruby-on-rails': 181, 'mysql': 173, 'iphone': 87, 'asp.net': 85, 'css': 77, 'node.js': 73, 'angular': 71, '.net': 64, 'sql-server': 63, 'git': 62, 'excel': 60, 'regex': 57, 'objective-c': 55, 'django': 55, 'linux': 51, 'ruby': 50, 'reactjs': 48, 'angularjs': 44, 'swift': 43, 'scala': 41, 'matlab': 41, 'xml': 40, 'python-3.x': 39, 'vba': 38, 'vb.net': 37, 'arrays': 36, 'powershell': 34, 'json': 34, 'bash': 33, 'windows': 30, 'wpf': 28, 'laravel': 27, 'spring': 27, 'wordpress': 25, 'asp.net-mvc': 24, 'mongodb': 24, 'amazon-web-services': 24, 'haskell': 23, 'delphi': 22, 'postgresql': 22, 'eclipse': 21, 'azure': 20, 'go': 19, 'visual-studio': 19, 'oracle': 18, 'perl': 18, 'typescript': 17, 'vue.js': 17, 'database': 16, 'xcode': 15, 'algorithm': 15, 'apache': 15, 'vim': 14, 'actionscript-3': 14, 'macos': 14, 'react-native': 14, 'flash': 12, 'visual-studio-2010': 12, 'facebook': 12, 'elasticsearch': 12, 'shell': 11, 'flutter': 11, 'docker': 11, 'kubernetes': 11, 'grails': 11, 'cassandra': 10, 'image': 10, 'xslt': 10, 'ember.js': 10, 'apache-spark': 10, 'google-apps-script': 10, 'f#': 10, 'firebase': 10, 'forms': 9, 'ajax': 9, 'python-2.7': 9, 'qt': 9, 'jenkins': 9, 'entity-framework': 8, 'linq': 8, 'github': 8, 'nginx': 8, 'tsql': 8, 'apache-flex': 8, 'assembly': 8, 'maven': 8, 'neo4j': 8, 'meteor': 8, 'debugging': 8, 'jsf': 8, 'svn': 8, 'silverlight': 8, 'http': 7, 'ms-access': 7, 'list': 7, 'security': 7, 'magento': 7, 'clojure': 7, 'unity3d': 7, 'google-sheets': 7, 'symfony': 7, 'asp.net-core': 7, 'string': 7, 'api': 7, 'opencv': 7, 'cordova': 7, 'dart': 7, 'multithreading': 6, 'hadoop': 6, 'jquery-ui': 6, 'sqlite': 6, 'ruby-on-rails-3': 6, 'asp.net-mvc-3': 6, 'pandas': 6, 'twitter-bootstrap': 6, 'backbone.js': 6, 'jsf-2': 6, 'rest': 6, 'jmeter': 6, 'svg': 6, 'tensorflow': 6, 'android-studio': 6, 'opengl': 6, 'extjs': 6, 'wcf': 6, 'unit-testing': 6, 'networking': 6, 'unix': 5, 'selenium': 5, 'google-app-engine': 5, 'validation': 5, 'ubuntu': 5, 'drupal': 5, 'asp.net-mvc-4': 5, 'fortran': 5, 'batch-file': 5, 'functional-programming': 5, 'ssl': 5, 'apache-kafka': 5, 'performance': 5, 'reporting-services': 5, 'sharepoint': 5, 'spring-boot': 5, 'kotlin': 5, 'redis': 4, 'mercurial': 4, 'sql-server-2008': 4, 'makefile': 4, 'wso2': 4, 'ansible': 4, 'google-chrome': 4, 'prolog': 4, 'emacs': 4, 'codeigniter': 4, 'sorting': 4, 'winforms': 4, 'gradle': 4, 'rust': 4, 'video': 4, 'tomcat': 4, 'crystal-reports': 4, 'ffmpeg': 4, 'cocoa': 4, 'google-bigquery': 4, 'gwt': 4, 'oop': 4, 'arduino': 4, '.htaccess': 4, 'exception': 4, 'authentication': 4, 'google-maps': 4, 'msbuild': 4, 'google-chrome-extension': 4, 'ocaml': 4, 'julia': 4, 'user-interface': 4, 'zend-framework': 4, 'windows-phone-7': 4, 'winapi': 4, 'iis': 3, 'database-design': 3, 'web-services': 3, 'audio': 3, 'session': 3, 'image-processing': 3, 'google-cloud-platform': 3, 'xaml': 3, 'rabbitmq': 3, 'csv': 3, 'configuration': 3, 'hibernate': 3, 'syntax': 3, 'typo3': 3, 'generics': 3, 'three.js': 3, 'kendo-ui': 3, 'dns': 3, 'solr': 3, 'javafx': 3, 'filter': 3, 'jsp': 3, 'orm': 3, 'machine-learning': 3, 'xamarin': 3, 'junit': 3, 'verilog': 3, 'erlang': 3, 'vbscript': 3, 'spring-mvc': 3, 'cakephp': 3, 'jupyter-notebook': 3, 'visual-studio-2012': 3, 'lua': 3, 'dataframe': 3, 'opengl-es': 3, 'jakarta-ee': 3, 'parsing': 3, 'web': 3, 'gcc': 3, 'vuejs2': 3, 'collections': 3, 'uwp': 3, 'function': 3, 'flask': 3, 'numpy': 3, 'elixir': 3, 'selenium-webdriver': 3, 'coldfusion': 3, 'swiftui': 3, 'types': 3, 'visual-studio-2008': 3, 'ipad': 3, 'testing': 2, 'cocoa-touch': 2, 'joomla': 2, 'google-drive-api': 2, 'installation': 2, 'version-control': 2, 'ios-simulator': 2, 'datetime': 2, 'text': 2, 'windows-services': 2, 'asp.net-web-api': 2, 'c++11': 2, 'autodesk-forge': 2, 'scripting': 2, 'sockets': 2, 'graphics': 2, 'asyn ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns


dataframe=pd.DataFrame.from_dict(counted_results, orient='index')
dataframe.head()

dataframe1=dataframe.reset_index()
dataframe2=dataframe1.rename(columns={"index":"Produktyp"})
dataframe2.columns=["Produkttyp", 'Numbers_of_Question']
dataframe2.head()
# Out:
#    Produkttyp  Numbers_of_Question
# 0         php                  657
# 1           c                  187
# 2          c#                  779
# 3  javascript                 1060
# 4         c++                  340

# %%
dataframe3= dataframe2.sort_values(by='Numbers_of_Question',ascending=False)
dataframe3.head()


dataframe4=dataframe3[dataframe3['Numbers_of_Question']>100]

dataframe4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15 entries, 3 to 17
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Produkttyp           15 non-null     object
#  1   Numbers_of_Question  15 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 360.0+ bytes

# %%
df = dataframe4
ax = df.plot.bar(x='Produkttyp', y='Numbers_of_Question', rot=0, width=0.7,figsize=(25,15))
plt.rcParams.update({'font.size': 10})
