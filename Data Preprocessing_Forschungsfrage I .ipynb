# %%
#Needed Package
import pandas as pd
import numpy as np

# %%
#Import of the data into the Jupiter Notebook 

#Import Code
df= pd.read_excel (r'daten_.xlsx')

# %%
#Visualize the data head
df.head()
# Out:
#          id                                              title  \
# 0  37992108                   My html form won't POST to mysql
# 1  38039505    Counting number of characters in a WCHAR string
# 2  30864424            How to get the appropriate ComboBox Tag
# 3  31033371                       Angular loop is not updating
# 4  30769186  why vector is always slower than C array, at l...
#
#                                                 body  accepted_answer_id  \
# 0  <p>Hello i have a problem where my data isn't ...            37994134
# 1  <p>Lua has a function named <code>utf8.len()</...            38083489
# 2  <p>I'm trying to get the Tag associated to a v...            30865517
# 3  <p>Just started out with angular. I was succes...            31034475
# 4  <p>I am trying to find all the primes not grea...            30769515
#
#    answer_count  comment_count community_owned_date  \
# 0             1             16                  NaN
# 1             1             25                  NaN
# 2             2             10                  NaN
# 3             2             13                  NaN
# 4             1             36                  NaN
#
#                  creation_date  favorite_count           last_activity_date  \
# 0  2016-06-23 12:47:34.017 UTC             0.0    2016-06-23 14:11:39.8 UTC
# 1  2016-06-26 14:29:23.597 UTC             NaN  2016-06-28 18:15:46.893 UTC
# 2   2015-06-16 10:01:14.49 UTC             0.0  2015-06-18 19:15:43.763 UTC
# 3  2015-06-24 17:40:05.553 UTC             NaN  2015-06-24 20:04:45.793 UTC
# 4   2015-06-10 23:43:19.39 UTC             NaN   2015-06-11 00:50:01.66 UTC
#
#    ...             last_edit_date_1 last_editor_display_name_1  \
# 0  ...                          NaN                        NaN
# 1  ...                          NaN                        NaN
# 2  ...  2015-06-16 12:25:59.613 UTC                        NaN
# 3  ...                          NaN                        NaN
# 4  ...   2015-06-11 00:50:01.66 UTC                        NaN
#
#    last_editor_user_id_1 owner_display_name_1  owner_user_id_1  parent_id_1  \
# 0                    NaN                  NaN        6498280.0     37992108
# 1                    NaN                  NaN        3408572.0     38039505
# 2              4984854.0                  NaN        4984854.0     30864424
# 3                    NaN                  NaN        2435473.0     31033371
# 4               257645.0                  NaN         257645.0     30769186
#
#    post_type_id_1  score_1 tags_1  view_count_1
# 0               2        0    NaN           NaN
# 1               2        1    NaN           NaN
# 2               2        1    NaN           NaN
# 3               2        1    NaN           NaN
# 4               2        7    NaN           NaN
#
# [5 rows x 40 columns]

# %%
#Visualize the data info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 40 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          10000 non-null  int64
#  1   title                       10000 non-null  object
#  2   body                        10000 non-null  object
#  3   accepted_answer_id          10000 non-null  int64
#  4   answer_count                10000 non-null  int64
#  5   comment_count               10000 non-null  int64
#  6   community_owned_date        4 non-null      object
#  7   creation_date               10000 non-null  object
#  8   favorite_count              2669 non-null   float64
#  9   last_activity_date          10000 non-null  object
#  10  last_edit_date              5612 non-null   object
#  11  last_editor_display_name    144 non-null    object
#  12  last_editor_user_id         5524 non-null   float64
#  13  owner_display_name          267 non-null    object
#  14  owner_user_id               9817 non-null   float64
#  15  parent_id                   0 non-null      float64
#  16  post_type_id                10000 non-null  int64
#  17  score                       10000 non-null  int64
#  18  tags                        10000 non-null  object
#  19  view_count                  10000 non-null  int64
#  20  id_1                        10000 non-null  int64
#  21  title_1                     0 non-null      float64
#  22  body_1                      10000 non-null  object
#  23  accepted_answer_id_1        0 non-null      float64
#  24  answer_count_1              0 non-null      float64
#  25  comment_count_1             10000 non-null  int64
#  26  community_owned_date_1      16 non-null     object
#  27  creation_date_1             10000 non-null  object
#  28  favorite_count_1            0 non-null      float64
#  29  last_activity_date_1        10000 non-null  object
#  30  last_edit_date_1            3587 non-null   object
#  31  last_editor_display_name_1  41 non-null     object
#  32  last_editor_user_id_1       3562 non-null   float64
#  33  owner_display_name_1        150 non-null    object
#  34  owner_user_id_1             9926 non-null   float64
#  35  parent_id_1                 10000 non-null  int64
#  36  post_type_id_1              10000 non-null  int64
#  37  score_1                     10000 non-null  int64
#  38  tags_1                      0 non-null      float64
#  39  view_count_1                0 non-null      float64
# dtypes: float64(12), int64(12), object(16)
# memory usage: 3.1+ MB

# %%
#Several Columns are not needed
#Dropped are: id_1, title_1, answer_count, score_1 ,body_1 , accepted_answer_id, score, comment_count, community_owned_date , creation_date, favorite_count, last_activity_date, last_edit_date ,last_editor_display_name, last_edit_date_1, last_editor_display_name_1, last_editor_user_id_1, owner_display_name_1, owner_user_id_1, parent_id_1, post_type_id_1, view_count, last_editor_user_id, owner_display_name, owner_user_id, parent_id, post_type_id, answer_count_1, answer_count_1, comment_count_1, community_owned_date_1, creation_date_1, favorite_count_1, last_activity_date_1, view_count_1, accepted_answer_id_1, tags_1
selected_dataframe = df.drop(['id_1','id','title_1','answer_count','score_1','body_1','accepted_answer_id', 'score','comment_count','community_owned_date','creation_date','favorite_count','last_activity_date','last_edit_date','last_editor_display_name','last_edit_date_1','last_editor_display_name_1','last_editor_user_id_1','owner_display_name_1','owner_user_id_1','parent_id_1','post_type_id_1','view_count','last_editor_user_id','owner_display_name','owner_user_id','parent_id','post_type_id','answer_count_1','answer_count_1','comment_count_1','community_owned_date_1','creation_date_1','favorite_count_1','last_activity_date_1','view_count_1','accepted_answer_id_1','tags_1'], axis=1)

# %%
#Remaining data are: 
#The title = The headline of a Mail 
#The body = The Main content of a Mail
#The tags = The subjektline 

#Visualize the remaining info
selected_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   10000 non-null  object
#  1   body    10000 non-null  object
#  2   tags    10000 non-null  object
# dtypes: object(3)
# memory usage: 234.5+ KB

# %%
#Visualize the remaining data head
selected_dataframe.head()
# Out:
#                                                title  \
# 0                   My html form won't POST to mysql
# 1    Counting number of characters in a WCHAR string
# 2            How to get the appropriate ComboBox Tag
# 3                       Angular loop is not updating
# 4  why vector is always slower than C array, at l...
#
#                                                 body  \
# 0  <p>Hello i have a problem where my data isn't ...
# 1  <p>Lua has a function named <code>utf8.len()</...
# 2  <p>I'm trying to get the Tag associated to a v...
# 3  <p>Just started out with angular. I was succes...
# 4  <p>I am trying to find all the primes not grea...
#
#                                             tags
# 0                            php|html|mysql|post
# 1                           c|winapi|unicode|lua
# 2                                c#|wpf|combobox
# 3  javascript|php|mysql|angularjs|angularjs-http
# 4                              c++|arrays|vector

# %%
#Create a new column for naming the labels
#In practise this would be the product category
#The product categories are = javascript = 1, java=2 , python=3, c#=4, php=5, android=6, c++=7, ios=8, others=9 
#We have decided that these are the products categroies which occure the most in the dataset; see Notebook "Data Exploration"
#The product category "others" can be reagarded as not product related questions from customers 

#Create a new column of NAN
sLength = len(selected_dataframe['ti'])
selected['Product_Category'] = pd.Series(np.nan, index=selected.index)

#Split each row at the 
# neue_liste=[]
# for i in range(len(selected)):
#     neue_liste.append(selected.loc[i,"tags"].split("|"))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'id'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-9214a90a6876> in <module>
#       6
#       7 #Create a new column of NAN
# ----> 8 sLength = len(selected_dataframe['id'])
#       9 selected['Product_Category'] = pd.Series(np.nan, index=selected.index)
#      10
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'id'

# %%
''
